# %%
name = "Akhil"

# %%
import pandas as pd
data = pd.read_csv("/content/Restaurant_Reviews.tsv",sep='\t')

# %%
data
# Out:
#                                                 Review  Liked
# 0                             Wow... Loved this place.      1
# 1                                   Crust is not good.      0
# 2            Not tasty and the texture was just nasty.      0
# 3    Stopped by during the late May bank holiday of...      1
# 4    The selection on the menu was great and so wer...      1
# ..                                                 ...    ...
# 995  I think food should have flavor and texture an...      0
# 996                           Appetite instantly gone.      0
# 997  Overall I was not impressed and would not go b...      0
# 998  The whole experience was underwhelming, and I ...      0
# 999  Then, as if I hadn't wasted enough of my life ...      0
#
# [1000 rows x 2 columns]

# %%
data.shape
# Out:
# (1000, 2)

# %%
pos = data[data["Liked"] == 1]

# %%
pos.head()
# Out:
#                                               Review  Liked
# 0                           Wow... Loved this place.      1
# 3  Stopped by during the late May bank holiday of...      1
# 4  The selection on the menu was great and so wer...      1
# 8                          The fries were great too.      1
# 9                                     A great touch.      1

# %%
pos.to_csv("pos",sep='\t')

# %%
# %%writefile test1.txt
# Hello, This is test file
# First line
# Second line
# Out:
# Writing test1.txt

# %%
# %%writefile -a test1.txt
# adding in append mode
# Out:
# Appending to test1.txt

# %%
file = open("test1.txt",mode='r')

# %%
file
# Out:
# <_io.TextIOWrapper name='test1.txt' mode='r' encoding='UTF-8'>

# %%
file.read()
# Out:
# 'Hello, This is test file\nFirst line\nSecond line\nadding in append mode\n'

# %%
file.read() #the file pointer has already reached the end of the line in the previous cell
# Out:
# ''

# %%
file.seek(0)
# Out:
# 0

# %%
file.read()
# Out:
# 'Hello, This is test file\nFirst line\nSecond line\nadding in append mode\n'

# %%
file.seek(5)
# Out:
# 5

# %%
file.read()
# Out:
# ', This is test file\nFirst line\nSecond line\nadding in append mode\n'

# %%
file.seek(0)
# Out:
# 0

# %%
file.readlines()
# Out:
# ['Hello, This is test file\n',
#  'First line\n',
#  'Second line\n',
#  'adding in append mode\n']

# %%
file.seek(0)
# Out:
# 0

# %%
file.readline()
# Out:
# 'Hello, This is test file\n'

# %%
file.readline()
# Out:
# 'First line\n'

# %%
file.seek(0) #this brings the file pointer to the starting of the file
# Out:
# 0

# %%
file.closed
# Out:
# False

# %%
file.close()

# %%
file.read()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-f3fc120c03c1> in <cell line: 1>()
# ----> 1 file.read()
#
# ValueError: I/O operation on closed file.

# %%
#in this method we dont want to worry about closing the file because the moment we exit the with block the file will be closed
with open("test1.txt",'r') as file:
  print(file.read())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-5aa13034e559> in <cell line: 2>()
#       1 #in this method we dont want to worry about closing the file because the moment we exit the with block the file will be closed
# ----> 2 with open("test1.txt",'r') as file:
#       3   print(file.read())
#
# FileNotFoundError: [Errno 2] No such file or directory: 'test1.txt'

# %%
with open("test1.txt",'r') as file:
  print(file.read().strip()) #strip will remove all the whitespace characters like \n \t
# Out:
# Hello, This is test file
# First line
# Second line
# adding in append mode

# %%
file_2 = open("test2.txt","w")

# %%
file_2.write("I am writing file from python")
# Out:
# 29

# %%
#if file is not closed the what ever we wrote using the write command wont be seen in the file
file_2.close()

# %%
with open("test3.txt",'w') as file:
  file.write("File writing in with block")

# %%
# !pip install -q PyPDF2

# %%
import PyPDF2 as pdf

# %%
file = open("sample.pdf",mode ='rb')

# %%
file
# Out:
# <_io.BufferedReader name='sample.pdf'>

# %%
pdf_reader = pdf.PdfReader(file)

# %%
len(pdf_reader.pages)
# Out:
# 2

# %%
page_1 = pdf_reader.pages[0]

# %%
print(page_1)
# Out:
# {'/Type': '/Page', '/Parent': IndirectObject(3, 0, 140067320911088), '/Resources': {'/Font': {'/F1': IndirectObject(9, 0, 140067320911088)}, '/ProcSet': IndirectObject(8, 0, 140067320911088)}, '/MediaBox': [0, 0, 612, 792], '/Contents': IndirectObject(5, 0, 140067320911088)}

# %%
page_1.extract_text()
# Out:
# ' A Simple PDF File \n This is a small demonstration .pdf file - \n just for use in the Virtual Mechanics tutorials. More text. And more \n text. And more text. And more text. And more text. \n And more text. And more text. And more text. And more text. And more \n text. And more text. Boring, zzzzz. And more text. And more text. And \n more text. And more text. And more text. And more text. And more text. \n And more text. And more text. \n And more text. And more text. And more text. And more text. And more \n text. And more text. And more text. Even more. Continued on page 2 ...'

# %%
file.close()

# %%
pdf_writer = pdf.PdfWriter()

# %%
output = open("new_sample.pdf","wb")

# %%
pdf_writer.add_page(page_1)
# Out:
# {'/Type': '/Page',
#  '/Resources': {'/Font': {'/F1': {'/Type': '/Font',
#     '/Subtype': '/Type1',
#     '/Name': '/F1',
#     '/BaseFont': '/Helvetica',
#     '/Encoding': '/WinAnsiEncoding'}},
#   '/ProcSet': ['/PDF', '/Text']},
#  '/MediaBox': [0, 0, 612, 792],
#  '/Contents': {},
#  '/Parent': {'/Type': '/Pages',
#   '/Count': 1,
#   '/Kids': [IndirectObject(7, 0, 140067320832496)]}}

# %%
pdf_writer.write(output)
# Out:
# (False, <_io.BufferedWriter name='new_sample.pdf'>)

# %%
output.close()
