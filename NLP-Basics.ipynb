# %% [markdown]
# 1) Tokenization Basics

# %%
s1 = 'Apple is looking at Buying U.K. startup for $1 billion !'
s2 = 'Hello all, We are here to help you! email support@udemy.com or visit at http://www.udemy.com!'
s3 = '10km cob ride almost costs $20 in NYC'
s4 = "Let's watch a movie together."

# %%
import spacy
# Out:
# /usr/local/lib/python3.9/dist-packages/torch/cuda/__init__.py:497: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")

# %%
nlp = spacy.load(name = 'en_core_web_sm')

# %%
# !python -m spacy download en_core_web_md

# %%
import en_core_web_md

# %%
nlp_1 = en_core_web_md.load()

# %%
doc1 = nlp(s1)

# %%
doc1
# Out:
# Apple is looking at Buying U.K. startup for $1 billion !

# %%
for token in doc1:
  print(token)
# Out:
# Apple
# is
# looking
# at
# Buying
# U.K.
# startup
# for
# $
# 1
# billion
# !

# %%
doc2=nlp(s2)
print(s2)
for token in doc2:
  print(token)
# Out:
# Hello all, We are here to help you! email support@udemy.com or visit at http://www.udemy.com!
# Hello
# all
# ,
# We
# are
# here
# to
# help
# you
# !
# email
# support@udemy.com
# or
# visit
# at
# http://www.udemy.com
# !

# %%
type(doc2)
# Out:
# spacy.tokens.doc.Doc

# %%
doc2
# Out:
# Hello all, We are here to help you! email support@udemy.com or visit at http://www.udemy.com!

# %%
len(doc2)
# Out:
# 17

# %%
doc2[0]
# Out:
# Hello

# %%
doc2[3:10]
# Out:
# We are here to help you!

# %%
doc2[-1]
# Out:
# !

# %%
doc2[0] = "New"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-1f377b116710> in <module>
# ----> 1 doc2[0] = "New"
#
# TypeError: 'spacy.tokens.doc.Doc' object does not support item assignment

# %% [markdown]
# 2) Stemming and Lemmatization

# %%
words = ['run','runnner','running','ran','runs','easily','fairly']

# %%
from nltk.stem.porter import PorterStemmer
from nltk.stem.snowball import SnowballStemmer

# %%
p_stemmer = PorterStemmer()
s_stemmer = SnowballStemmer(language='english')

# %%
for word in words:
  print(word + ' --------- '+ p_stemmer.stem(word))
# Out:
# run --------- run
# runnner --------- runnner
# running --------- run
# ran --------- ran
# runs --------- run
# easily --------- easili
# fairly --------- fairli

# %%
for word in words:
  print(word + ' --------- '+ s_stemmer.stem(word))
# Out:
# run --------- run
# runnner --------- runnner
# running --------- run
# ran --------- ran
# runs --------- run
# easily --------- easili
# fairly --------- fair

# %%
document_1 = nlp("The stripped bats are hanging on their feet for best")

# %%
for token in document_1:
  print(token.text + ' ----- ' +token.lemma_)
# Out:
# The ----- the
# stripped ----- strip
# bats ----- bat
# are ----- be
# hanging ----- hang
# on ----- on
# their ----- their
# feet ----- foot
# for ----- for
# best ----- good

# %% [markdown]
# 3) Stopwords

# %%
print(nlp.Defaults.stop_words)
# Out:
# {'keep', 'this', 'do', 'else', 'everywhere', 'never', 'across', "'ll", 'both', 'perhaps', 'just', 'has', 'sometimes', 'whenever', 'it', 'however', 'its', 'least', 'namely', 'ca', 'an', 'latterly', 'various', 'side', 'eleven', 'myself', 'cannot', 'everything', 'another', 'down', 'could', 'alone', 'above', 'done', 'when', 'seem', 'latter', 'must', 'always', 'became', 'regarding', 'well', 'why', 'noone', 'were', 'quite', 'fifteen', 'much', 'is', 'hers', 'might', 'yours', 'become', 'formerly', 'thereafter', 'made', 'twelve', 'behind', 'anyhow', "n't", 're', 'if', 'them', '’ll', 'less', 'elsewhere', 'should', 'n‘t', 'than', 'how', 'anywhere', 'something', 'by', 'sometime', 'whereupon', 'there', 'mostly', 'neither', 'amount', 'would', 'many', 'six', 'you', 'several', '’d', 'such', 'been', 'one', 'who', 'under', 'seemed', 'becomes', 'after', 'for', 'their', 'whoever', 'two', 'bottom', 'same', 'so', 'am', 'therefore', 'upon', 'nobody', 'indeed', 'not', 'itself', 'himself', 'others', 'everyone', 'ours', 'below', '’re', 'say', '‘m', 'very', 'three', '‘s', 'our', 'someone', 'then', 'all', 'until', 'whether', 'move', 'the', 'here', 'whose', 'that', 'meanwhile', '’m', 'over', 'in', 'to', 'forty', 'first', 'of', 'take', 'somehow', "'m", 'through', 'was', 'my', 'nor', 'onto', 'via', 'are', 'from', 'too', 'a', 'where', 'own', 'part', 'or', 'herein', 'may', 'seems', 'now', "'d", 'wherever', 'next', 'ourselves', 'mine', 'which', 'anyone', 'more', 'every', 'although', 'ever', 'his', 'therein', 'five', 'give', 'few', 'be', 'throughout', 'he', 'each', 'further', 'we', 'seeming', 'during', 'thence', '’ve', 'whole', 'beside', 'anyway', 'former', 'nowhere', 'up', 'had', 'using', 'sixty', 'she', 'becoming', 'hundred', 'other', 'and', 'hereafter', 'yourself', 'thereby', 'him', 'beforehand', 'her', 'these', '’s', 'please', 'toward', 'into', "'re", 'hereby', 'call', 'eight', 'whence', 'nothing', 'since', 'yet', 'before', 'nevertheless', 'fifty', 'us', 'along', 'again', 'some', 'at', 'about', 'whom', 'whereby', '‘re', 'front', 'full', 'go', 'n’t', 'whatever', 'even', 'most', 'what', 'but', 'twenty', 'otherwise', 'i', 'among', 'empty', 'once', 'out', 'besides', "'s", 'will', 'per', 'with', 'beyond', 'already', 'back', 'show', 'make', 'name', 'together', 'ten', 'have', 'moreover', '‘ve', 'towards', 'thus', 'hence', 'without', 'no', 'see', 'they', 'none', 'four', 'does', 'while', 'third', 'me', 'only', 'almost', 'on', 'also', 'really', 'whither', 'thru', 'due', 'still', 'hereupon', 'yourselves', 'because', 'did', 'herself', 'your', 'nine', 'around', 'those', "'ve", 'unless', 'themselves', 'thereupon', 'enough', 'being', 'get', 'as', 'whereas', 'put', 'used', 'serious', 'either', 'can', 'except', '‘d', 'any', 'often', 'somewhere', 'amongst', 'between', 'afterwards', 'within', 'anything', 'doing', 'top', '‘ll', 'though', 'off', 'wherein', 'against', 'whereafter', 'rather', 'last'}

# %%
len(nlp.Defaults.stop_words)
# Out:
# 326

# %%
nlp.vocab['always'].is_stop
# Out:
# True

# %%
nlp.vocab['finance'].is_stop
# Out:
# False

# %%
nlp.vocab['tatatata'].is_stop
# Out:
# False

# %%
nlp.Defaults.stop_words.add('tatatata')

# %%
nlp.vocab['tatatata'].is_stop = True

# %%
len(nlp.Defaults.stop_words)
# Out:
# 327

# %%
print(nlp.vocab)
# Out:
# <spacy.vocab.Vocab object at 0x7f6b0002dd30>

# %% [markdown]
# 4) Rule Based Matching

# %%
from spacy.matcher import Matcher
matcher = Matcher(nlp.vocab)

# %%
pattern_1 = [{'LOWER':'hello'},{'LOWER':'world'}]
pattern_2 = [{'LOWER':'hello'},{'IS_PUNCT':True},{'LOWER':'world'}]

# %%
matcher.add('Hello World',None,pattern_1,pattern_2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-3188d5962ccd> in <module>
# ----> 1 matcher.add('Hello World',None,pattern_1,pattern_2)
#
# /usr/local/lib/python3.9/dist-packages/spacy/matcher/matcher.pyx in spacy.matcher.matcher.Matcher.add()
#
# TypeError: add() takes exactly 2 positional arguments (4 given)

# %%
find_matches = matcher(doc_1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-70f50843137b> in <module>
# ----> 1 find_matches = matcher(doc_1)
#
# NameError: name 'doc_1' is not defined

# %% [markdown]
# 5) Phrase Based Matching

# %% [markdown]
# 6) POS Tagging

# %%
s1 = "Apple is looking at buying U.K. startup for $1 buillion"

# %%
doc = nlp(s1)

# %%
for token in doc:
  print(token.text,token.pos_,token.tag_,spacy.explain(token.tag_))
# Out:
# Apple PROPN NNP noun, proper singular
# is AUX VBZ verb, 3rd person singular present
# looking VERB VBG verb, gerund or present participle
# at ADP IN conjunction, subordinating or preposition
# buying VERB VBG verb, gerund or present participle
# U.K. PROPN NNP noun, proper singular
# startup NOUN NN noun, singular or mass
# for ADP IN conjunction, subordinating or preposition
# $ SYM $ symbol, currency
# 1 NUM CD cardinal number
# buillion NOUN NN noun, singular or mass

# %%
for key,val in doc.count_by(spacy.attrs.POS).items():
  print(key, doc.vocab[key].text,val)
# Out:
# 96 PROPN 2
# 87 AUX 1
# 100 VERB 2
# 85 ADP 2
# 92 NOUN 2
# 99 SYM 1
# 93 NUM 1

# %%
from spacy import displacy

# %%
displacy.render(docs = doc,style='dep',options={'distance':80},jupyter = True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="ebfb6a6e900f47a880fe956b01d5dd9e-0" class="displacy" width="930" height="217.0" direction="ltr" style="max-width: none; height: 217.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="127.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Apple</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="127.0">
#     <tspan class="displacy-word" fill="currentColor" x="130">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="130">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="127.0">
#     <tspan class="displacy-word" fill="currentColor" x="210">looking</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="210">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="127.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">at</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="127.0">
#     <tspan class="displacy-word" fill="currentColor" x="370">buying</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="370">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="127.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">U.K.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="127.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">startup</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="127.0">
#     <tspan class="displacy-word" fill="currentColor" x="610">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="610">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="127.0">
#     <tspan class="displacy-word" fill="currentColor" x="690">$</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="690">SYM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="127.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">1</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="127.0">
#     <tspan class="displacy-word" fill="currentColor" x="850">buillion</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="850">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-ebfb6a6e900f47a880fe956b01d5dd9e-0-0" stroke-width="2px" d="M70,82.0 C70,2.0 210.0,2.0 210.0,82.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-ebfb6a6e900f47a880fe956b01d5dd9e-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,84.0 L62,72.0 78,72.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-ebfb6a6e900f47a880fe956b01d5dd9e-0-1" stroke-width="2px" d="M150,82.0 C150,42.0 205.0,42.0 205.0,82.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-ebfb6a6e900f47a880fe956b01d5dd9e-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">aux</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M150,84.0 L142,72.0 158,72.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-ebfb6a6e900f47a880fe956b01d5dd9e-0-2" stroke-width="2px" d="M230,82.0 C230,42.0 285.0,42.0 285.0,82.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-ebfb6a6e900f47a880fe956b01d5dd9e-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M285.0,84.0 L293.0,72.0 277.0,72.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-ebfb6a6e900f47a880fe956b01d5dd9e-0-3" stroke-width="2px" d="M310,82.0 C310,42.0 365.0,42.0 365.0,82.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-ebfb6a6e900f47a880fe956b01d5dd9e-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pcomp</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M365.0,84.0 L373.0,72.0 357.0,72.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-ebfb6a6e900f47a880fe956b01d5dd9e-0-4" stroke-width="2px" d="M390,82.0 C390,42.0 445.0,42.0 445.0,82.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-ebfb6a6e900f47a880fe956b01d5dd9e-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M445.0,84.0 L453.0,72.0 437.0,72.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-ebfb6a6e900f47a880fe956b01d5dd9e-0-5" stroke-width="2px" d="M230,82.0 C230,2.0 530.0,2.0 530.0,82.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-ebfb6a6e900f47a880fe956b01d5dd9e-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M530.0,84.0 L538.0,72.0 522.0,72.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-ebfb6a6e900f47a880fe956b01d5dd9e-0-6" stroke-width="2px" d="M550,82.0 C550,42.0 605.0,42.0 605.0,82.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-ebfb6a6e900f47a880fe956b01d5dd9e-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M605.0,84.0 L613.0,72.0 597.0,72.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-ebfb6a6e900f47a880fe956b01d5dd9e-0-7" stroke-width="2px" d="M710,82.0 C710,42.0 765.0,42.0 765.0,82.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-ebfb6a6e900f47a880fe956b01d5dd9e-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M710,84.0 L702,72.0 718,72.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-ebfb6a6e900f47a880fe956b01d5dd9e-0-8" stroke-width="2px" d="M790,82.0 C790,42.0 845.0,42.0 845.0,82.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-ebfb6a6e900f47a880fe956b01d5dd9e-0-8" class="displacy-

# %% [markdown]
# 7) Named Entity Recognition

# %%
s1 = "Apple is looking at buying U.K. startup for $1 billion"
s2 = "San Francisco considers banning sidewalk delivery robots"
s3 = "Facebook is hiring a new vice president in U.S."

# %%
   doc1 = nlp(s1)
for ent in doc1.ents:
  print(ent.text, ent.label_, str(spacy.explain(ent.label_)))
# Out:
# Apple ORG Companies, agencies, institutions, etc.
# U.K. GPE Countries, cities, states
# $1 billion MONEY Monetary values, including unit

# %%
doc2 = nlp(s2)
for ent in doc2.ents:
  print(ent.text, ent.label_, str(spacy.explain(ent.label_)))
# Out:
# San Francisco GPE Countries, cities, states

# %%
doc3 = nlp(s3)
for ent in doc3.ents:
  print(ent.text, ent.label_, str(spacy.explain(ent.label_)))
# Out:
# Facebook ORG Companies, agencies, institutions, etc.
# U.S. GPE Countries, cities, states

# %% [markdown]
# Adding a new word into a entity

# %%
ORG = doc3.vocab.strings['ORG']

# %%
from spacy.tokens import Span
new_ent = Span(doc3 , 0, 1, label = ORG)

# %%
doc3.ents = list(doc3.ents) + [new_ent]

# %%
doc3.ents
# Out:
# (Facebook, U.S.)

# %%
for ent in doc3.ents:
  print(ent.text, ent.label_, str(spacy.explain(ent.label_)))
# Out:
# Facebook ORG Companies, agencies, institutions, etc.
# U.S. GPE Countries, cities, states

# %%
displacy.render(docs = doc1, style = 'ent' , jupyter = True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is looking at buying
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     U.K.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  startup for
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $1 billion
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# </div></span>

# %%
displacy.render(docs = doc1, style = 'ent' , options = {'ents':['ORG']},jupyter = True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is looking at buying U.K. startup for $1 billion</div></span>

# %% [markdown]
# 8)  Sentence Segmentation

# %%
s1= "This is a sentence. This is second sentence. This is last sentence."
s2= "This is a sentence ; This is second sentence ; This is last sentence."

# %%
doc1 = nlp(s1)

# %%
doc1.sents

# %%
for sent in doc1.sents:
  print(sent.text)
# Out:
# This is a sentence.
# This is second sentence.
# This is last sentence.

# %%
s3= "This is a sentence. This is second  U.K. sentence. This is last sentence."

# %%
doc3=nlp(s3)
for sent in doc3.sents:
  print(sent.text)
# Out:
# This is a sentence.
# This is second  U.K. sentence.
# This is last sentence.

# %%
doc2=nlp(s2)
for sent in doc2.sents:
  print(sent.text)
# Out:
# This is a sentence; This is second sentence; This is last sentence.

# %%
from spacy.language import Language
@Language.component("set_custom_boundary")
def set_custom_boundary(doc):
   for token in doc[:-1]:
     if token.text == ';':
       print(token.i)
       doc[token.i+1].is_sent_start = True
   return doc

# %%
nlp.pipe_names
# Out:
# ['tok2vec', 'tagger', 'parser', 'attribute_ruler', 'lemmatizer', 'ner']

# %%
nlp.add_pipe('set_custom_boundary',before="parser")
# Out:
# <function __main__.set_custom_boundary(doc)>

# %%
nlp.pipe_names
# Out:
# ['tok2vec',
#  'tagger',
#  'set_custom_boundary',
#  'parser',
#  'attribute_ruler',
#  'lemmatizer',
#  'ner']

# %%
doc_2 = nlp(s2)
for sent in doc_2.sents:
  print(sent.text)
# Out:
# 4
# 9
# This is a sentence ;
# This is second sentence ;
# This is last sentence.
