# %%
import pandas as pd
import numpy as np

# %%
my_data = [10,20,30,40,50]
labels = ['a','b','c','d','e']

# %%
pd.Series(data = my_data)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
pd.Series(data = my_data,index = labels)
# Out:
# a    10
# b    20
# c    30
# d    40
# e    50
# dtype: int64

# %% [markdown]
# Creating pandas series using numpy array

# %%
arr = np.array(my_data)

# %%
arr
# Out:
# array([10, 20, 30, 40, 50])

# %%
pd.Series(data = arr)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %% [markdown]
# Creating pandas series using dictionaries

# %%
d  = {'a':100,'b':200,'c':300,'d':400}

# %%
pd.Series(d)
# Out:
# a    100
# b    200
# c    300
# d    400
# dtype: int64

# %%
pd.Series(data = labels)
# Out:
# 0    a
# 1    b
# 2    c
# 3    d
# 4    e
# dtype: object

# %%
pd.Series(data=[sum,len])
# Out:
# 0    <built-in function sum>
# 1    <built-in function len>
# dtype: object

# %%
ser1 = pd.Series(data = [1,2,3,4],index = ['Red','Green','Blue','Orange'])

# %%
ser1
# Out:
# Red       1
# Green     2
# Blue      3
# Orange    4
# dtype: int64

# %%
ser2 = pd.Series(data = [1,2,5,4],index = ['Red','Green','Yellow','Orange'])

# %%
ser2
# Out:
# Red       1
# Green     2
# Yellow    5
# Orange    4
# dtype: int64

# %%
ser2['Green']
# Out:
# 2

# %%
ser1['Blue']
# Out:
# 3

# %%
ser3 = pd.Series(data=['a','b','c','d','e'])

# %%
ser3
# Out:
# 0    a
# 1    b
# 2    c
# 3    d
# 4    e
# dtype: object

# %%
ser3[1]
# Out:
# 'b'

# %%
ser3[0:3]
# Out:
# 0    a
# 1    b
# 2    c
# dtype: object

# %%
ser1+ser2 #pandas series do addition on the basis of labels and are arranged in alphebetical order
# Out:
# Blue      NaN
# Green     4.0
# Orange    8.0
# Red       2.0
# Yellow    NaN
# dtype: float64

# %% [markdown]
# Dataframes

# %%
from numpy.random import randn
np.random.seed(101)

# %%
df = pd.DataFrame(data = randn(5,4),index = ['a','b','c','d','e'],columns =['w','x','y','z'])

# %%
df
# Out:
#           w         x         y         z
# a  2.706850  0.628133  0.907969  0.503826
# b  0.651118 -0.319318 -0.848077  0.605965
# c -2.018168  0.740122  0.528813 -0.589001
# d  0.188695 -0.758872 -0.933237  0.955057
# e  0.190794  1.978757  2.605967  0.683509

# %%
df['w']
# Out:
# a    2.706850
# b    0.651118
# c   -2.018168
# d    0.188695
# e    0.190794
# Name: w, dtype: float64

# %%
type(df['w'])
# Out:
# pandas.core.series.Series

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df[['x','y']]
# Out:
#           x         y
# a  0.628133  0.907969
# b -0.319318 -0.848077
# c  0.740122  0.528813
# d -0.758872 -0.933237
# e  1.978757  2.605967

# %%
df['new'] = df['w']+df['x']

# %%
df
# Out:
#           w         x         y         z       new
# a  2.706850  0.628133  0.907969  0.503826  3.334983
# b  0.651118 -0.319318 -0.848077  0.605965  0.331800
# c -2.018168  0.740122  0.528813 -0.589001 -1.278046
# d  0.188695 -0.758872 -0.933237  0.955057 -0.570177
# e  0.190794  1.978757  2.605967  0.683509  2.169552

# %%
df.drop(labels='new',axis =1)
# Out:
#           w         x         y         z
# a  2.706850  0.628133  0.907969  0.503826
# b  0.651118 -0.319318 -0.848077  0.605965
# c -2.018168  0.740122  0.528813 -0.589001
# d  0.188695 -0.758872 -0.933237  0.955057
# e  0.190794  1.978757  2.605967  0.683509

# %%
df
# Out:
#           w         x         y         z       new
# a  2.706850  0.628133  0.907969  0.503826  3.334983
# b  0.651118 -0.319318 -0.848077  0.605965  0.331800
# c -2.018168  0.740122  0.528813 -0.589001 -1.278046
# d  0.188695 -0.758872 -0.933237  0.955057 -0.570177
# e  0.190794  1.978757  2.605967  0.683509  2.169552

# %%
df.drop(labels='new',axis =1,inplace = True)

# %%
df
# Out:
#           w         x         y         z
# a  2.706850  0.628133  0.907969  0.503826
# b  0.651118 -0.319318 -0.848077  0.605965
# c -2.018168  0.740122  0.528813 -0.589001
# d  0.188695 -0.758872 -0.933237  0.955057
# e  0.190794  1.978757  2.605967  0.683509

# %%
df.drop('b',axis = 0)
# Out:
#           w         x         y         z
# a  2.706850  0.628133  0.907969  0.503826
# c -2.018168  0.740122  0.528813 -0.589001
# d  0.188695 -0.758872 -0.933237  0.955057
# e  0.190794  1.978757  2.605967  0.683509

# %%
df.loc['c']
# Out:
# w   -2.018168
# x    0.740122
# y    0.528813
# z   -0.589001
# Name: c, dtype: float64

# %%
type(df.loc['c'])
# Out:
# pandas.core.series.Series

# %%
df.loc['c','x']
# Out:
# 0.7401220570561068

# %%
df.loc['d':,'y':]
# Out:
#           y         z
# d -0.933237  0.955057
# e  2.605967  0.683509

# %%
df.loc[['d','e'],['y','z']]
# Out:
#           y         z
# d -0.933237  0.955057
# e  2.605967  0.683509

# %%
df
# Out:
#           w         x         y         z
# a  2.706850  0.628133  0.907969  0.503826
# b  0.651118 -0.319318 -0.848077  0.605965
# c -2.018168  0.740122  0.528813 -0.589001
# d  0.188695 -0.758872 -0.933237  0.955057
# e  0.190794  1.978757  2.605967  0.683509

# %%
df > 0
# Out:
#        w      x      y      z
# a   True   True   True   True
# b   True  False  False   True
# c  False   True   True  False
# d   True  False  False   True
# e   True   True   True   True

# %%
df[df>0]
# Out:
#           w         x         y         z
# a  2.706850  0.628133  0.907969  0.503826
# b  0.651118       NaN       NaN  0.605965
# c       NaN  0.740122  0.528813       NaN
# d  0.188695       NaN       NaN  0.955057
# e  0.190794  1.978757  2.605967  0.683509

# %%
df['w'] > 0
# Out:
# a     True
# b     True
# c    False
# d     True
# e     True
# Name: w, dtype: bool

# %%
df[df['w'] > 0]
# Out:
#           w         x         y         z
# a  2.706850  0.628133  0.907969  0.503826
# b  0.651118 -0.319318 -0.848077  0.605965
# d  0.188695 -0.758872 -0.933237  0.955057
# e  0.190794  1.978757  2.605967  0.683509

# %%
df[(df['w']>0) & (df['y']>1)]
# Out:
#           w         x         y         z
# e  0.190794  1.978757  2.605967  0.683509

# %%
df[(df['w']>0) | (df['y']>1)]
# Out:
#           w         x         y         z
# a  2.706850  0.628133  0.907969  0.503826
# b  0.651118 -0.319318 -0.848077  0.605965
# d  0.188695 -0.758872 -0.933237  0.955057
# e  0.190794  1.978757  2.605967  0.683509

# %%
df.reset_index()
# Out:
#   index         w         x         y         z
# 0     a  2.706850  0.628133  0.907969  0.503826
# 1     b  0.651118 -0.319318 -0.848077  0.605965
# 2     c -2.018168  0.740122  0.528813 -0.589001
# 3     d  0.188695 -0.758872 -0.933237  0.955057
# 4     e  0.190794  1.978757  2.605967  0.683509

# %%
new_index= ['R','G','B','O','Y']

# %%
df['Colors'] = new_index

# %%
df
# Out:
#           w         x         y         z Colors
# a  2.706850  0.628133  0.907969  0.503826      R
# b  0.651118 -0.319318 -0.848077  0.605965      G
# c -2.018168  0.740122  0.528813 -0.589001      B
# d  0.188695 -0.758872 -0.933237  0.955057      O
# e  0.190794  1.978757  2.605967  0.683509      Y

# %%
df.set_index('Colors')
# Out:
#                w         x         y         z
# Colors
# R       2.706850  0.628133  0.907969  0.503826
# G       0.651118 -0.319318 -0.848077  0.605965
# B      -2.018168  0.740122  0.528813 -0.589001
# O       0.188695 -0.758872 -0.933237  0.955057
# Y       0.190794  1.978757  2.605967  0.683509

# %%
outside = ['Red','Red','Red','Green','Green','Green']
inside = [1,2,3,1,2,3]

# %%
hier_index = list(zip(outside,inside))

# %%
hier_index
# Out:
# [('Red', 1), ('Red', 2), ('Red', 3), ('Green', 1), ('Green', 2), ('Green', 3)]

# %%
multi_index = pd.MultiIndex.from_tuples(hier_index,names = ['Colors','Numbers'])

# %%
multi_index
# Out:
# MultiIndex([(  'Red', 1),
#             (  'Red', 2),
#             (  'Red', 3),
#             ('Green', 1),
#             ('Green', 2),
#             ('Green', 3)],
#            names=['Colors', 'Numbers'])

# %%
df = pd.DataFrame(data = randn(6,2),index = multi_index,columns =["A","B"])

# %%
df
# Out:
#                        A         B
# Colors Numbers
# Red    1        0.302665  1.693723
#        2       -1.706086 -1.159119
#        3       -0.134841  0.390528
# Green  1        0.166905  0.184502
#        2        0.807706  0.072960
#        3        0.638787  0.329646

# %%
df.loc['Red']
# Out:
#                 A         B
# Numbers
# 1        0.302665  1.693723
# 2       -1.706086 -1.159119
# 3       -0.134841  0.390528

# %%
df.loc['Red'].loc[1]
# Out:
# A    0.302665
# B    1.693723
# Name: 1, dtype: float64

# %%
df.loc['Red'].loc[1]['A']
# Out:
# 0.3026654485851825

# %%
df.loc['Green'].loc[2]
# Out:
# A    0.807706
# B    0.072960
# Name: 2, dtype: float64

# %%
df.index.names
# Out:
# FrozenList(['Colors', 'Numbers'])

# %%
df.index.names = ['Col','Num']

# %%
df
# Out:
#                   A         B
# Col   Num
# Red   1    0.302665  1.693723
#       2   -1.706086 -1.159119
#       3   -0.134841  0.390528
# Green 1    0.166905  0.184502
#       2    0.807706  0.072960
#       3    0.638787  0.329646

# %%
#Cross Section

# %%
df.loc['Red']
# Out:
#             A         B
# Num
# 1    0.302665  1.693723
# 2   -1.706086 -1.159119
# 3   -0.134841  0.390528

# %%
df.xs('Red')
# Out:
#             A         B
# Num
# 1    0.302665  1.693723
# 2   -1.706086 -1.159119
# 3   -0.134841  0.390528

# %%
df.xs(1,level = 'Num')
# Out:
#               A         B
# Col
# Red    0.302665  1.693723
# Green  0.166905  0.184502

# %%
d = {'A':[1,2,np.nan],'B':[3,np.nan,np.nan],'C':[4,5,6]}

# %%
d
# Out:
# {'A': [1, 2, nan], 'B': [3, nan, nan], 'C': [4, 5, 6]}

# %%
df = pd.DataFrame(d)

# %%
df
# Out:
#      A    B  C
# 0  1.0  3.0  4
# 1  2.0  NaN  5
# 2  NaN  NaN  6

# %%
df.dropna() #by default axis is 0, so dropped all the rows with null values
# Out:
#      A    B  C
# 0  1.0  3.0  4

# %%
df.dropna(axis =1 )
# Out:
#    C
# 0  4
# 1  5
# 2  6

# %%
df.dropna(thresh = 2)
# Out:
#      A    B  C
# 0  1.0  3.0  4
# 1  2.0  NaN  5

# %%
df.dropna(thresh = 2, axis =1)
# Out:
#      A  C
# 0  1.0  4
# 1  2.0  5
# 2  NaN  6

# %%
df.fillna(value = 'New Value')
# Out:
#            A          B  C
# 0        1.0        3.0  4
# 1        2.0  New Value  5
# 2  New Value  New Value  6

# %%
df['A'].fillna(value = df['A'].mean())
# Out:
# 0    1.0
# 1    2.0
# 2    1.5
# Name: A, dtype: float64

# %%
team_data = {'Company':['Apple','Apple','FB','FB','Google','Google'],
             'Person':['Mark','Tom','John','Sara','Mia','Emma'],
             'Sales':[200,150,350,260,180,170]}

# %%
team_data
# Out:
# {'Company': ['Apple', 'Apple', 'FB', 'FB', 'Google', 'Google'],
#  'Person': ['Mark', 'Tom', 'John', 'Sara', 'Mia', 'Emma'],
#  'Sales': [200, 150, 350, 260, 180, 170]}

# %%
df = pd.DataFrame(team_data)

# %%
df
# Out:
#   Company Person  Sales
# 0   Apple   Mark    200
# 1   Apple    Tom    150
# 2      FB   John    350
# 3      FB   Sara    260
# 4  Google    Mia    180
# 5  Google   Emma    170

# %%
df.groupby(by='Company')

# %%
b =df.groupby(by='Company')

# %%
b.mean()
# Out:
#          Sales
# Company
# Apple    175.0
# FB       305.0
# Google   175.0

# %%
b.sum()
# Out:
#          Sales
# Company
# Apple      350
# FB         610
# Google     350

# %%
b.std()
# Out:
#              Sales
# Company
# Apple    35.355339
# FB       63.639610
# Google    7.071068

# %%
b.sum().loc['Apple']
# Out:
# Sales    350
# Name: Apple, dtype: int64

# %%
df.groupby(by='Company').sum().loc['FB']
# Out:
# Sales    610
# Name: FB, dtype: int64

# %%
b.count()
# Out:
#          Person  Sales
# Company
# Apple         2      2
# FB            2      2
# Google        2      2

# %%
b.max()
# Out:
#         Person  Sales
# Company
# Apple      Tom    200
# FB        Sara    350
# Google     Mia    180

# %%
b.min()
# Out:
#         Person  Sales
# Company
# Apple     Mark    150
# FB        John    260
# Google    Emma    170

# %%
df.groupby(by='Company').describe()
# Out:
#         Sales
#         count   mean        std    min    25%    50%    75%    max
# Company
# Apple     2.0  175.0  35.355339  150.0  162.5  175.0  187.5  200.0
# FB        2.0  305.0  63.639610  260.0  282.5  305.0  327.5  350.0
# Google    2.0  175.0   7.071068  170.0  172.5  175.0  177.5  180.0

# %%
df.groupby(by='Company').describe().transpose()
# Out:
# Company           Apple         FB      Google
# Sales count    2.000000    2.00000    2.000000
#       mean   175.000000  305.00000  175.000000
#       std     35.355339   63.63961    7.071068
#       min    150.000000  260.00000  170.000000
#       25%    162.500000  282.50000  172.500000
#       50%    175.000000  305.00000  175.000000
#       75%    187.500000  327.50000  177.500000
#       max    200.000000  350.00000  180.000000

# %%
df.groupby(by='Company').describe().loc['Google']
# Out:
# Sales  count      2.000000
#        mean     175.000000
#        std        7.071068
#        min      170.000000
#        25%      172.500000
#        50%      175.000000
#        75%      177.500000
#        max      180.000000
# Name: Google, dtype: float64

# %%
df1=pd.DataFrame({'A':['A0','A1','A2','A3'],
                  'B':['B0','B1','B2','B3'],
                  'C':['C0','C1','C2','C3'],
                  'D': ['D0','D1','D2','D3']},
                   index = [0, 1, 2, 3])
 
df2=pd.DataFrame({'A':['A4','A5','A6','A7'],
                  'B':['B4','B5','B6','B7'],
                  'C':['C4','C5','C6','C7'],
                  'D':['D4','D5','D6','D7']},
                   index = [4, 5, 6, 7])
 
df3=pd.DataFrame({'A':['A8','A9','A10','A11'],
                  'B':['B8','B9','B10','B11'],
                  'C':['C8','C9','C10','C11'],
                  'D':['D8','D9','D10','D11']},
                   index = [8, 9, 10, 11])

# %%
df1
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3

# %%
df2
# Out:
#     A   B   C   D
# 4  A4  B4  C4  D4
# 5  A5  B5  C5  D5
# 6  A6  B6  C6  D6
# 7  A7  B7  C7  D7

# %%
df3
# Out:
#       A    B    C    D
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %%
pd.concat(objs=[df1,df2,df3])
# Out:
#       A    B    C    D
# 0    A0   B0   C0   D0
# 1    A1   B1   C1   D1
# 2    A2   B2   C2   D2
# 3    A3   B3   C3   D3
# 4    A4   B4   C4   D4
# 5    A5   B5   C5   D5
# 6    A6   B6   C6   D6
# 7    A7   B7   C7   D7
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %%
pd.concat(objs=[df1,df2,df3],axis =1)
# Out:
#       A    B    C    D    A    B    C    D    A    B    C    D
# 0    A0   B0   C0   D0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1    A1   B1   C1   D1  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2    A2   B2   C2   D2  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3    A3   B3   C3   D3  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4   NaN  NaN  NaN  NaN   A4   B4   C4   D4  NaN  NaN  NaN  NaN
# 5   NaN  NaN  NaN  NaN   A5   B5   C5   D5  NaN  NaN  NaN  NaN
# 6   NaN  NaN  NaN  NaN   A6   B6   C6   D6  NaN  NaN  NaN  NaN
# 7   NaN  NaN  NaN  NaN   A7   B7   C7   D7  NaN  NaN  NaN  NaN
# 8   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   A8   B8   C8   D8
# 9   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   A9   B9   C9   D9
# 10  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  A10  B10  C10  D10
# 11  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  A11  B11  C11  D11

# %%
df4=pd.DataFrame({'Key':['K0','K1','K2','K3'],
                   'A':['A0','A1','A2','A3'],
                   'B':['B0','B1','B2','B3']})
 
df5=pd.DataFrame({'Key':['K0','K1','K2','K3'],
                    'C':['C0','C1','C2','C3'],
                    'D':['D0','D1','D2','D3']})

# %%
df4
# Out:
#   Key   A   B
# 0  K0  A0  B0
# 1  K1  A1  B1
# 2  K2  A2  B2
# 3  K3  A3  B3

# %%
df5
# Out:
#   Key   C   D
# 0  K0  C0  D0
# 1  K1  C1  D1
# 2  K2  C2  D2
# 3  K3  C3  D3

# %%
pd.merge(left=df4,right = df5,on ='Key')
# Out:
#   Key   A   B   C   D
# 0  K0  A0  B0  C0  D0
# 1  K1  A1  B1  C1  D1
# 2  K2  A2  B2  C2  D2
# 3  K3  A3  B3  C3  D3

# %%
df6 = pd.DataFrame({'key1': ['K0', 'K0', 'K1', 'K2'],
                     'key2': ['K0', 'K1', 'K0', 'K1'],
                        'A': ['A0', 'A1', 'A2', 'A3'],
                        'B': ['B0', 'B1', 'B2', 'B3']})
    
df7 = pd.DataFrame({'key1': ['K0', 'K1', 'K1', 'K2'],
                               'key2': ['K0', 'K0', 'K0', 'K0'],
                                  'C': ['C0', 'C1', 'C2', 'C3'],
                                  'D': ['D0', 'D1', 'D2', 'D3']})

# %%
df6
# Out:
#   key1 key2   A   B
# 0   K0   K0  A0  B0
# 1   K0   K1  A1  B1
# 2   K1   K0  A2  B2
# 3   K2   K1  A3  B3

# %%
df7
# Out:
#   key1 key2   C   D
# 0   K0   K0  C0  D0
# 1   K1   K0  C1  D1
# 2   K1   K0  C2  D2
# 3   K2   K0  C3  D3

# %%
pd.merge(left = df6,right = df7, on =['key1','key2'])
# Out:
#   key1 key2   A   B   C   D
# 0   K0   K0  A0  B0  C0  D0
# 1   K1   K0  A2  B2  C1  D1
# 2   K1   K0  A2  B2  C2  D2

# %%
df8 = pd.DataFrame({'A':['A0','A1','A2','A3'],
                  'B':['B0','B1','B2','B3']},
                    index=['K0','K1','K2','K3'])
 
df9 = pd.DataFrame({'C':['C0','C1','C2','C3'],
                  'D':['D0','D1','D2','D3']},
                    index=['K0','K1','K2','K3'])

# %%
df8
# Out:
#      A   B
# K0  A0  B0
# K1  A1  B1
# K2  A2  B2
# K3  A3  B3

# %%
df9
# Out:
#      C   D
# K0  C0  D0
# K1  C1  D1
# K2  C2  D2
# K3  C3  D3

# %%
df8.join(df9)
# Out:
#      A   B   C   D
# K0  A0  B0  C0  D0
# K1  A1  B1  C1  D1
# K2  A2  B2  C2  D2
# K3  A3  B3  C3  D3

# %%
d = {'col1':[1,2,3,4],
     'col2':[45,55,65,45],
     'col3':['asd','jkl','qwe','xyz']}

# %%
df = pd.DataFrame(d)

# %%
df
# Out:
#    col1  col2 col3
# 0     1    45  asd
# 1     2    55  jkl
# 2     3    65  qwe
# 3     4    45  xyz

# %%
df['col2'].unique()
# Out:
# array([45, 55, 65])

# %%
len(df['col2'].unique())
# Out:
# 3

# %%
df['col2'].nunique()
# Out:
# 3

# %%
df['col2'].value_counts()
# Out:
# 45    2
# 55    1
# 65    1
# Name: col2, dtype: int64

# %%
def times5(x):
  return x*5

# %%
times5(10)
# Out:
# 50

# %%
df['col1'].sum()
# Out:
# 10

# %%
df['col1'].apply(times5)
# Out:
# 0     5
# 1    10
# 2    15
# 3    20
# Name: col1, dtype: int64

# %%
df['col3'].apply(len)
# Out:
# 0    3
# 1    3
# 2    3
# 3    3
# Name: col3, dtype: int64

# %%
df.drop('col1',axis=1)
# Out:
#    col2 col3
# 0    45  asd
# 1    55  jkl
# 2    65  qwe
# 3    45  xyz

# %%
df.columns
# Out:
# Index(['col1', 'col2', 'col3'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
df.sort_values('col2')
# Out:
#    col1  col2 col3
# 0     1    45  asd
# 3     4    45  xyz
# 1     2    55  jkl
# 2     3    65  qwe

# %%
df.isnull()
# Out:
#     col1   col2   col3
# 0  False  False  False
# 1  False  False  False
# 2  False  False  False
# 3  False  False  False
